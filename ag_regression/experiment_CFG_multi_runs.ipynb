# %%
from ponyge2_adapted_files import Grammar, ge
import algorithms
from os import path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from deap import creator, base, tools
from sklearn.model_selection import train_test_split
import math
import textwrap
import csv

import warnings
warnings.filterwarnings("ignore")

# %%
x = np.arange(0, 100)
y = lambda x: x**4 + x**3 + x**2 + x
# noise = 100* np.random.normal(0, 1, size=x.shape)
# y_noised = y(x) + noise

# X_train, X_test, y_train, y_test = train_test_split(x, y_noised, test_size=0.1, shuffle=True)

# %%
plt.scatter(x, y(x))
plt.title("Target Function")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
# plt.scatter(X_test, y_test)
# plt.title("Test data")
# plt.xlabel("x")
# plt.ylabel("y")
# plt.show()

# %%
X_train = np.array([x/10. for x in range(-100,100)])
y_train = y(X_train)

X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.1, shuffle=True)

# %%
GRAMMAR_FILE = 'basic-regression-grammar.bnf'
BNF_GRAMMAR = Grammar(path.join("../grammars", GRAMMAR_FILE))

# %%
def write_stat(value, file_name, mode):
    with open(file_name, mode) as write_file:
        write_file.write(str(value))
        write_file.write("\n")


def read_stat(file_name):
    with open(file_name, "r") as write_file:
        cnt = int(write_file.read())
    return cnt

# %%
### cold-start
with open("out-files/statistics-cfg.txt", "w") as write_file:
    # write_file.write(str(0))
    write_file.write(str(""))

# %%
ε = 1e-8

def fitness_eval(individual, points):
    #points = [X, Y]
    x = points[0]
    y = points[1]
    
    if individual.invalid == True:
        return np.NaN,
    try:
        pred = eval(individual.phenotype)
        # pred = eval(parse(individual.phenotype))
    # except (FloatingPointError, ZeroDivisionError, OverflowError,
    #         MemoryError, ValueError):
    except Exception as e:
        # cnt = read_stat("out-files/statistics-cfg.txt") + 1
        # write_stat(cnt, "out-files/statistics-cfg.txt")
        write_stat(e, "out-files/statistics-cfg.txt", "a")
        return np.NaN,
    assert np.isrealobj(pred)
    
    try:
        # fitness = 1/np.mean(np.square(y - pred))
        fitness = np.mean(np.square(y - pred))
    # except (FloatingPointError, ZeroDivisionError, OverflowError,
    #         MemoryError, ValueError):
    except Exception as e:
        # cnt = read_stat("out-files/statistics-cfg.txt") + 1
        # write_stat(cnt, "out-files/statistics-cfg.txt")
        write_stat(e, "out-files/statistics-cfg.txt", "a")
        fitness = np.NaN
        
    if fitness == float("inf"):
        return np.NaN,
    # if fitness > 10000:
    #     return 10000,
    return fitness,

# %%
toolbox = base.Toolbox()

# define a single objective, minimising fitness strategy:
# creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))


# creator.create('Individual', ge.Individual, fitness=creator.FitnessMax)
creator.create('Individual', ge.Individual, fitness=creator.FitnessMin)

toolbox.register("populationCreator", ge.initialisation_PI_Grow, creator.Individual) 

toolbox.register("evaluate", fitness_eval)#, points=[X_train, Y_train])

# Tournament selection:
toolbox.register("select", ge.selTournament, tournsize=3)

# Single-point crossover:
toolbox.register("mate", ge.crossover_onepoint)

# Flip-int mutation:
toolbox.register("mutate", ge.mutation_int_flip_per_codon)

# %%
N_RUNS = 32
POPULATION_SIZE = 200
MAX_GENERATIONS = 20
P_CROSSOVER = 0.9
P_MUTATION = 0.01
ELITE_SIZE = round(0.01*POPULATION_SIZE)

HALL_OF_FAME_SIZE = 1
MAX_INIT_TREE_DEPTH = 5
MIN_INIT_TREE_DEPTH = 1
MAX_TREE_DEPTH = 17
MAX_WRAPS = 0
CODON_SIZE = 255

# %%
maxListFitness = []
avgListFitness = []
minListFitness = []
stdListFitness = []

maxListSize = []
avgListSize = []
minListSize = []
stdListSize = []
bestListSize = []

# %%
for r in range(0, N_RUNS):
    # create initial population (generation 0):
    population = toolbox.populationCreator(size=POPULATION_SIZE, 
                                            bnf_grammar=BNF_GRAMMAR, 
                                            min_init_tree_depth=MIN_INIT_TREE_DEPTH,
                                            max_init_tree_depth=MAX_INIT_TREE_DEPTH,
                                            max_tree_depth=MAX_TREE_DEPTH, 
                                            max_wraps=MAX_WRAPS,
                                            codon_size=CODON_SIZE
                                            )
    # define the hall-of-fame object:
    hof = tools.HallOfFame(HALL_OF_FAME_SIZE)             
    # prepare the statistics object:
    #stats = tools.Statistics(key=lambda ind: ind.fitness.values if math.isnan(ind.fitness.values[0]) else None)#ind.fitness.values != np.inf else None)
    #stats = tools.Statistics(key=lambda ind: ind.fitness.values[0] if not math.isnan(ind.fitness.values[0]) else np.NaN)#ind.fitness.values != np.inf else None)
    stats = tools.Statistics(key=lambda ind: ind.fitness.values)# if not ind.invalid else (np.NaN,))#ind.fitness.values != np.inf else None)
    stats.register("avg", np.nanmean)
    stats.register("std", np.nanstd)
    stats.register("min", np.nanmin)
    stats.register("max", np.nanmax)
    
    # Which run are we on?
    print("\n\nCurrently on run", r, "of",N_RUNS)
    # perform the Grammatical Evolution flow:
    population, logbook = algorithms.ge_eaSimpleWithElitism(population, toolbox, cxpb=P_CROSSOVER, mutpb=P_MUTATION,
                                          ngen=MAX_GENERATIONS, elite_size=ELITE_SIZE,
                                          bnf_grammar=BNF_GRAMMAR, codon_size=CODON_SIZE, 
                                          max_tree_depth=MAX_TREE_DEPTH, max_wraps=MAX_WRAPS,
                                          points_train=[X_train, y_train], 
                                          points_test=[X_test, y_test], 
                                          stats=stats, halloffame=hof, verbose=True)

    max_fitness_values, mean_fitness_values = logbook.select("max", "avg")
    min_fitness_values, std_fitness_values = logbook.select("min", "std")
    
    # fitness_test = logbook.select("fitness_test")
    best_ind_length = logbook.select("best_ind_length")
    avg_length = logbook.select("avg_length")
    max_length = logbook.select("max_length")
    # selection_time = logbook.select("selection_time")
    # generation_time = logbook.select("generation_time")
    # gen, invalid = logbook.select("gen", "invalid")

    # Save statistics for this run:
    avgListFitness.append(mean_fitness_values)
    stdListFitness.append(std_fitness_values)
    minListFitness.append(min_fitness_values)
    maxListFitness.append(max_fitness_values)

    avgListSize.append(avg_length)
    bestListSize.append(best_ind_length)
    # stdListSize.append(stdSizeValues)
    # minListSize.append(minSizeValues)
    maxListSize.append(max_length)

    # best = hof.items[0].phenotype # parser to change the individual 
    best = parse(hof.items[0].phenotype) # parser to change the individual 
    print("Best individual: \n","\n".join(textwrap.wrap(best,80)))
    print("\nTraining Fitness: ", hof.items[0].fitness.values[0])
    print("Depth: ", hof.items[0].depth)
    print("Length of the genome: ", len(hof.items[0].genome))
    print(f'Used portion of the genome: {hof.items[0].used_codons/len(hof.items[0].genome):.2f}')     
    write_stat("end of run", "out-files/statistics-cfg.txt", "a")
# Out:
# Currently on run 0 of 32
# gen	invalid	avg        	std    	min       	max        	fitness_test	best_ind_length	avg_length	max_length	selection_time	generation_time
# 0  	0      	1.17825e+07	4486.96	1.1772e+07	1.18004e+07	nan         	19             	8.46      	22        	0             	0.0149157
# 1  	68     	1.17801e+07	3217.06	1.17686e+07	1.17913e+07	8.42461e+06 	25             	8.695     	25        	0.00110126    	0.0530386
# 2  	41     	1.17779e+07	3430.27	1.17676e+07	1.17867e+07	8.42461e+06 	12             	11.4      	32        	0.00162673    	0.0289237
# 3  	30     	1.17763e+07	3684.67	1.1764e+07 	1.17872e+07	nan         	23             	13.99     	34        	0.000901461   	0.0240951
# 4  	21     	1.17747e+07	4568.14	1.17635e+07	1.17872e+07	nan         	29             	17.135    	35        	0.000965118   	0.0227265
# 5  	25     	1.17727e+07	6079.41	1.17545e+07	1.17872e+07	nan         	28             	19.395    	39        	0.000890493   	0.0253317
# 6  	19     	1.17698e+07	6051.82	1.17544e+07	1.17913e+07	nan         	55             	23.16     	55        	0.000912428   	0.0231752
# 7  	13     	1.17661e+07	7235.1 	1.17404e+07	1.17867e+07	nan         	41             	27.08     	59        	0.000865936   	0.0278277
# 8  	19     	1.17616e+07	10199.3	1.17358e+07	1.17867e+07	nan         	54             	31.775    	67        	0.0010426     	0.0328338
# 9  	16     	1.17561e+07	13866.1	1.1721e+07 	1.17867e+07	nan         	77             	39.525    	78        	0.0012114     	0.0401366
# 10 	16     	1.17469e+07	17903.1	1.17022e+07	1.17867e+07	nan         	93             	50.185    	110       	0.00113177    	0.0449929
# 11 	34     	1.17396e+07	23598  	1.16839e+07	1.17867e+07	nan         	87             	62.755    	125       	0.000881672   	0.043705
# 12 	33     	1.17299e+07	21833.1	1.16806e+07	1.17822e+07	nan         	109            	72.765    	134       	0.000873089   	0.0471923
# 13 	38     	1.17241e+07	28121.7	1.16329e+07	1.17781e+07	nan         	145            	83.36     	170       	0.000984907   	0.0603685
# 14 	52     	1.17161e+07	31599.5	1.16329e+07	1.17817e+07	nan         	145            	97.19     	200       	0.00332284    	0.0624335
# 15 	50     	1.1712e+07 	39028.3	1.16173e+07	1.17867e+07	nan         	154            	115.48    	235       	0.00116444    	0.0618234
# 16 	61     	1.17018e+07	40801.3	1.15761e+07	1.17776e+07	nan         	249            	124.24    	302       	0.000889301   	0.0681152
# 17 	66     	1.16965e+07	49481  	1.15736e+07	1.17822e+07	nan         	177            	134.58    	307       	0.00116491    	0.0676939
# 18 	64     	1.1682e+07 	54235.4	1.15187e+07	1.17867e+07	nan         	218            	156.98    	396       	0.00167727    	0.0876744
# 19 	67     	1.1674e+07 	51551.6	1.15187e+07	1.17731e+07	nan         	218            	189.915   	324       	0.000932455   	0.0804448
# 20 	65     	1.16679e+07	60590.3	1.15115e+07	1.17822e+07	nan         	419            	210       	450       	0.00105095    	0.0914061
# Best individual:
#  x[0]+x[0]+x[0]*x[0]*x[0]+x[0]/(x[0]+ε)+x[0]+x[0]+x[0]+x[0]-x[0]+x[0]*x[0]-x[0]*x
# [0]+x[0]+x[0]+x[0]-x[0]+x[0]/(x[0]+ε)+x[0]*x[0]+x[0]*x[0]*x[0]+x[0]/(x[0]+ε)+x[0
# ]*x[0]+x[0]*x[0]*x[0]/(x[0]+ε)+x[0]-x[0]+x[0]*x[0]+x[0]+x[0]+x[0]*x[0]+x[0]-x[0]
# +x[0]*x[0]+x[0]+x[0]*x[0]*x[0]+x[0]*x[0]+x[0]+x[0]*x[0]/(x[0]+ε)+x[0]*x[0]+x[0]+
# x[0]*x[0]/(x[0]+ε)+x[0]/(x[0]+ε)+x[0]*x[0]*x[0]*x[0]+x[0]*x[0]*x[0]+x[0]*x[0]/(x
# [0]+ε)+x[0]+x[0]+x[0]*x[0]*x[0]+x[0]*x[0]+x[0]*x[0]/(x[0]+ε)+x[0]/(x[0]+ε)*x[0]*
# x[0]/(x[0]+ε)+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]*x[0]+x[0]*x[0]+x[0]+x[0]*x
# [0]+x[0]+x[0]+x[0]-x[0]-x[0]+x[0]+x[0]+x[0]+x[0]-x[0]+x[0]-x[0]+x[0]*x[0]+x[0]+x
# [0]+x[0]*x[0]+x[0]+x[0]*x[0]
#
# Training Fitness:  11511518.226580324
# Depth:  16
# Length of the genome:  419
# Used portion of the genome: 0.59
#
#
# Currently on run 1 of 32
# gen	invalid	avg        	std    	min        	max        	fitness_test	best_ind_length	avg_length	max_length	selection_time	generation_time
# 0  	0      	1.17828e+07	4711.11	1.17644e+07	1.17958e+07	nan         	21             	8.465     	22        	0             	0.00891495
# 1  	67     	1.17796e+07	4645.18	1.17635e+07	1.17867e+07	8.42125e+06 	21             	8.41      	33        	0.00120521    	0.0562382
# 2  	45     	1.17771e+07	5020.29	1.17594e+07	1.17867e+07	nan         	22             	13.365    	34        	0.00119853    	0.0248594
# 3  	22     	1.17739e+07	6071.97	1.17499e+07	1.17859e+07	nan         	32             	16.545    	39        	0.00105739    	0.0234122
# 4  	23     	1.17699e+07	7765.1 	1.17459e+07	1.17867e+07	nan         	31             	18.96     	46        	0.000961304   	0.0395045
# 5  	18     	1.17649e+07	9280.77	1.17304e+07	1.17913e+07	nan         	57             	22.805    	57        	0.000977516   	0.0329747
# 6  	31     	1.1758e+07 	13058.8	1.17072e+07	1.17822e+07	nan         	62             	29.82     	65        	0.0015111     	0.0429273
# 7  	26     	1.17514e+07	18185.1	1.16875e+07	1.17867e+07	nan         	74             	38.3      	83        	0.00125527    	0.0466533
# 8  	27     	1.1741e+07 	23738.4	1.16765e+07	1.17867e+07	nan         	83             	48.2      	125       	0.000914574   	0.0394621
# 9  	41     	1.17322e+07	26677  	1.16515e+07	1.17867e+07	nan         	94             	56.845    	133       	0.000965118   	0.050946
# 10 	44     	1.1718e+07 	31116.2	1.16322e+07	1.17822e+07	nan         	113            	67.64     	161       	0.00390673    	0.0540445
# 11 	53     	1.17033e+07	41558.1	1.15913e+07	1.17812e+07	nan         	154            	84.195    	181       	0.000928402   	0.0604231
# 12 	54     	1.16878e+07	43894.6	1.15428e+07	1.17681e+07	nan         	179            	105.385   	238       	0.00187087    	0.184978
# 13 	50     	1.1674e+07 	53068.5	1.15203e+07	1.17867e+07	nan         	223            	117.93    	242       	0.00220513    	0.0986149
# 14 	67     	1.16676e+07	63150.6	1.14798e+07	1.17822e+07	nan         	283            	136.05    	283       	0.000939369   	0.10504
# 15 	62     	1.16577e+07	67178.4	1.14798e+07	1.17822e+07	nan         	283            	158.085   	349       	0.00105095    	0.101112
# 16 	57     	1.16582e+07	70900.2	1.14719e+07	1.17781e+07	nan         	290            	172.305   	371       	0.00207925    	0.12775
# 17 	73     	1.16618e+07	75459.7	1.14243e+07	1.17826e+07	nan         	464            	186.945   	464       	0.00213194    	0.10603
# 18 	63     	1.16471e+07	80471.6	1.14007e+07	1.17867e+07	nan         	489            	214.035   	666       	0.00110936    	0.0921812
# 19 	68     	1.16477e+07	87720.4	1.14007e+07	1.17781e+07	nan         	489            	259.815   	848       	0.000919104   	0.0945959
# 20 	71     	1.16532e+07	83836  	1.14007e+07	1.17781e+07	nan         	489            	296.795   	790       	0.000941038   	0.0994494
# Best individual:
#  x[0]+1+x[0]+x[0]*x[0]+1+1+x[0]+x[0]+x[0]+x[0]+x[0]/1+x[0]+x[0]+x[0]*x[0]*x[0]+x[
# 0]+x[0]+x[0]*x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+1+x[0]+x[0]+x[0]+x[0]+x[0]-
# x[0]+x[0]*x[0]+1+x[0]+x[0]+x[0]+x[0]*x[0]+x[0]*x[0]+x[0]/(x[0]+ε)*x[0]/1+x[0]+x[
# 0]+x[0]+x[0]+x[0]+1+x[0]/(x[0]+ε)+x[0]*x[0]+x[0]+x[0]+1*x[0]+x[0]+x[0]*x[0]*x[0]
# +1+x[0]/(x[0]+ε)+x[0]+x[0]+x[0]+1+x[0]*x[0]+x[0]*x[0]+x[0]+x[0]+x[0]+x[0]*x[0]*1
# *x[0]+x[0]*x[0]*x[0]+x[0]+x[0]+x[0]*x[0]+x[0]/(x[0]+ε)+x[0]/1+x[0]+x[0]+x[0]+x[0
# ]*x[0]+x[0]+1+x[0]*1+x[0]+x[0]+x[0]*x[0]*x[0]+x[0]+x[0]+x[0]*x[0]+x[0]/(x[0]+ε)+
# x[0]+x[0]+x[0]+x[0]/(x[0]+ε)
#
# Training Fitness:  11400728.504003186
# Depth:  17
# Length of the genome:  489
# Used portion of the genome: 0.53
#
#
# Currently on run 2 of 32
# gen	invalid	avg        	std    	min        	max        	fitness_test	best_ind_length	avg_length	max_length	selection_time	generation_time
# 0  	0      	1.17823e+07	5002.77	1.17626e+07	1.18008e+07	8.42461e+06 	22             	8.415     	22        	0             	0.00620461
# 1  	69     	1.1781e+07 	4075.78	1.17626e+07	1.17963e+07	8.42461e+06 	22             	10.005    	25        	0.000889301   	0.0562375
# 2  	37     	1.17786e+07	4899.66	1.17599e+07	1.17867e+07	8.42125e+06 	20             	12.65     	34        	0.00110745    	0.0268612
# 3  	33     	1.17755e+07	6224.87	1.17549e+07	1.17867e+07	8.42125e+06 	26             	15.535    	43        	0.000869513   	0.0228639
# 4  	34     	1.17712e+07	8450.55	1.17426e+07	1.17872e+07	nan         	32             	18.965    	40        	0.0015521     	0.0269105
# 5  	29     	1.17661e+07	10495.5	1.17322e+07	1.17826e+07	nan         	48             	23.43     	51        	0.00186968    	0.0255334
# 6  	26     	1.17603e+07	13141.1	1.17137e+07	1.17867e+07	8.41454e+06 	51             	28.64     	64        	0.000874996   	0.0260739
# 7  	25     	1.17517e+07	15914.9	1.16861e+07	1.17788e+07	nan         	75             	35.09     	75        	0.0011754     	0.0305433
# 8  	25     	1.1742e+07 	21273.1	1.16606e+07	1.17817e+07	8.41119e+06 	74             	43.16     	92        	0.0013907     	0.0367882
# 9  	33     	1.17289e+07	27543.6	1.16123e+07	1.17822e+07	8.40449e+06 	112            	53.16     	112       	0.00090003    	0.0456743
# 10 	46     	1.17238e+07	40738.3	1.16078e+07	1.17822e+07	8.40449e+06 	131            	66.25     	146       	0.00132442    	0.0454016
# 11 	39     	1.17072e+07	43018.3	1.15866e+07	1.17822e+07	nan         	163            	81.28     	224       	0.000953913   	0.0635531
# 12 	64     	1.17035e+07	48892.6	1.15751e+07	1.17822e+07	nan         	152            	96.09     	218       	0.00115967    	0.0701985
# 13 	57     	1.1688e+07 	54079.9	1.15412e+07	1.17776e+07	nan         	167            	117.71    	301       	0.0017705     	0.0715778
# 14 	62     	1.16787e+07	55565.1	1.14806e+07	1.17776e+07	nan         	244            	129.545   	301       	0.00158429    	0.0907896
# 15 	62     	1.16738e+07	61516.2	1.14806e+07	1.17867e+07	nan         	244            	148.765   	326       	0.00234151    	0.0798225
# 16 	64     	1.16678e+07	65374  	1.14806e+07	1.17776e+07	nan         	244            	169.12    	412       	0.00108123    	0.0818169
# 17 	69     	1.16568e+07	70904.1	1.14726e+07	1.17822e+07	8.3978e+06  	245            	186.635   	441       	0.00104856    	0.0997403
# 18 	79     	1.16458e+07	77708.1	1.14266e+07	1.17822e+07	nan         	273            	197.38    	414       	0.00161672    	0.096626
# 19 	73     	1.16373e+07	87253.9	1.13243e+07	1.17867e+07	nan         	361            	216.855   	441       	0.00129843    	0.0960073
# 20 	75     	1.16328e+07	85619.1	1.13243e+07	1.17867e+07	nan         	361            	246.315   	582       	0.000993252   	0.109181
# Best individual:
#  x[0]*x[0]+x[0]-x[0]/(x[0]+ε)*x[0]+x[0]+x[0]+x[0]+x[0]+x[0]*x[0]+1+x[0]+x[0]+x[0]
# +x[0]+1+x[0]+1+x[0]+x[0]+0+x[0]+x[0]+x[0]+x[0]+1+x[0]+x[0]+x[0]+1+x[0]+x[0]*x[0]
# *x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+1+x[0]+x[0]+x[0]+x[0]+1+x[0]+x[0]*x[0]/(x[0]
# +ε)+x[0]+x[0]+x[0]/(x[0]+ε)+1+x[0]+x[0]+x[0]*x[0]+x[0]+x[0]+x[0]-x[0]+x[0]+1+x[0
# ]+x[0]+x[0]+x[0]+1+0*1+x[0]+x[0]+x[0]*x[0]+0+x[0]+x[0]*x[0]+x[0]+x[0]+x[0]+x[0]+
# x[0]+1+x[0]+x[0]*x[0]+x[0]+x[0]+0*x[0]+x[0]+x[0]+1+0+x[0]+x[0]+x[0]+1+x[0]+x[0]*
# x[0]+x[0]+x[0]+x[0]+x[0]*x[0]+x[0]+1+x[0]+x[0]+x[0]+x[0]+1+x[0]+1+x[0]+x[0]*x[0]
# +x[0]+x[0]+x[0]+x[0]+x[0]+x[0]*x[0]+1+x[0]+x[0]
#
# Training Fitness:  11324340.425272206
# Depth:  16
# Length of the genome:  361
# Used portion of the genome: 0.80
#
#
# Currently on run 3 of 32
# gen	invalid	avg        	std    	min        	max        	fitness_test	best_ind_length	avg_length	max_length	selection_time	generation_time
# 0  	0      	1.17831e+07	5231.89	1.17681e+07	1.18009e+07	nan         	19             	8.325     	22        	0             	0.0118594
# 1  	49     	1.1781e+07 	4392.07	1.1764e+07 	1.17917e+07	8.42125e+06 	18             	8.12      	26        	0.00120044    	0.129644
# 2  	43     	1.17778e+07	4930.92	1.17635e+07	1.17867e+07	nan         	29             	11.715    	31        	0.00106835    	0.0267
# 3  	26     	1.17749e+07	5490.54	1.17594e+07	1.17913e+07	nan         	37             	15.415    	37        	0.00109029    	0.0299277
# 4  	30     	1.17723e+07	6343.18	1.17508e+07	1.17867e+07	nan         	28             	17.3      	38        	0.00325847    	0.0340333
# 5  	25     	1.17686e+07	8352.45	1.17413e+07	1.17871e+07	nan         	25             	22.07     	56        	0.000992775   	0.0280735
# 6  	17     	1.17644e+07	10554.5	1.17327e+07	1.17822e+07	nan         	59             	26.93     	79        	0.00169516    	0.0382288
# 7  	16     	1.17583e+07	12707.9	1.17203e+07	1.1783e+07 	nan         	59             	32.45     	80        	0.0011766     	0.0392649
# 8  	8      	1.17514e+07	15345.4	1.1706e+07 	1.17867e+07	nan         	59             	38.985    	92        	0.00219727    	0.0516493
# 9  	23     	1.17434e+07	19409.4	1.1684e+07 	1.17781e+07	nan         	77             	45.675    	92        	0.00194645    	0.0501022
# 10 	28     	1.17364e+07	23817.7	1.16557e+07	1.17826e+07	nan         	97             	52.76     	132       	0.001122      	0.050746
# 11 	28     	1.17265e+07	29012.2	1.16501e+07	1.17867e+07	nan         	104            	64.54     	177       	0.00116801    	0.0576732
# 12 	44     	1.17198e+07	31697.4	1.1649e+07 	1.17826e+07	nan         	115            	76.655    	184       	0.00126028    	0.0521691
# 13 	33     	1.17053e+07	34234  	1.16013e+07	1.17822e+07	nan         	147            	86.19     	203       	0.000910044   	0.0638909
# 14 	38     	1.17014e+07	39010  	1.15784e+07	1.17867e+07	nan         	149            	100.3     	271       	0.00100923    	0.0640674
# 15 	48     	1.16917e+07	43549.1	1.15513e+07	1.17822e+07	nan         	159            	115.91    	326       	0.00169301    	0.0808909
# 16 	49     	1.16833e+07	44814.1	1.15513e+07	1.1769e+07 	nan         	159            	128.825   	263       	0.00168777    	0.0754378
# 17 	48     	1.16816e+07	52832.5	1.15513e+07	1.17822e+07	nan         	159            	134.685   	263       	0.000967026   	0.0770712
# 18 	54     	1.16674e+07	62978.4	1.14553e+07	1.17776e+07	nan         	253            	152.885   	351       	0.000939369   	0.0790105
# 19 	62     	1.16531e+07	69089.7	1.14553e+07	1.17726e+07	nan         	253            	170.585   	367       	0.00198507    	0.107126
# 20 	60     	1.16525e+07	68819.6	1.14553e+07	1.17826e+07	nan         	253            	185.76    	386       	0.0010972     	0.0955102
# Best individual:
#  x[0]+x[0]*x[0]+x[0]+x[0]/(x[0]+ε)+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]*x[
# 0]+x[0]/(x[0]+ε)+x[0]+x[0]/(x[0]+ε)+x[0]+x[0]+0+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+1*0
# *x[0]+x[0]+x[0]/(x[0]+ε)+x[0]+x[0]*x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]/
# (x[0]+ε)+x[0]+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]*x[0]+x[0]+x[0]/(x[0]+ε)+x[0]+x[0
# ]+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]+x[0]/(x[0]+ε)/(x[0]+ε)*x[0]+x[0]+x[0]-x[0]+x
# [0]+x[0]+x[0]+x[0]+x[0]*x[0]+x[0]+x[0]/(x[0]+ε)+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]/(x
# [0]+ε)+x[0]*x[0]+x[0]*x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]/(x[
# 0]+ε)+x[0]/(x[0]+ε)
#
# Training Fitness:  11455321.396114536
# Depth:  16
# Length of the genome:  253
# Used portion of the genome: 0.84
#
#
# Currently on run 4 of 32
# gen	invalid	avg        	std    	min       	max        	fitness_test	best_ind_length	avg_length	max_length	selection_time	generation_time
# 0  	0      	1.17828e+07	4828.85	1.1764e+07	1.18017e+07	nan         	19             	8.525     	22        	0             	0.0111141
# 1  	65     	1.17797e+07	4696.33	1.17599e+07	1.17913e+07	nan         	21             	8.53      	29        	0.00152445    	0.0491147
# 2  	51     	1.1777e+07 	5406.54	1.17599e+07	1.17973e+07	nan         	21             	11.905    	29        	0.00139809    	0.0294204
# 3  	33     	1.17725e+07	5561.99	1.17549e+07	1.17848e+07	nan         	24             	15.04     	35        	0.00218463    	0.0338748
# 4  	32     	1.17684e+07	6462.49	1.17409e+07	1.17867e+07	nan         	38             	18.315    	41        	0.00128031    	0.0386205
# 5  	35     	1.17645e+07	9089.09	1.17309e+07	1.17822e+07	nan         	35             	21.69     	47        	0.00108671    	0.0327535
# 6  	27     	1.17579e+07	11615.7	1.17192e+07	1.17817e+07	nan         	43             	27.36     	55        	0.000949621   	0.0371034
# 7  	20     	1.17512e+07	14898.3	1.17056e+07	1.17867e+07	nan         	56             	32.895    	72        	0.00113964    	0.0486498
# 8  	20     	1.17452e+07	17908.4	1.16957e+07	1.17867e+07	nan         	64             	40.99     	83        	0.00107956    	0.0369771
# 9  	33     	1.17351e+07	20083.2	1.16647e+07	1.17731e+07	nan         	69             	47.57     	90        	0.00100756    	0.0488737
# 10 	33     	1.17237e+07	24612  	1.16412e+07	1.17826e+07	nan         	105            	58.31     	114       	0.000922203   	0.0543711
# 11 	36     	1.17218e+07	34341.8	1.16212e+07	1.17822e+07	nan         	128            	65.43     	134       	0.000853062   	0.0517852
# 12 	49     	1.17073e+07	43196.2	1.15758e+07	1.17822e+07	nan         	165            	83.26     	165       	0.00104427    	0.0546641
# 13 	46     	1.16942e+07	45598.6	1.15355e+07	1.17812e+07	nan         	177            	100.275   	222       	0.00182915    	0.0766609
# 14 	53     	1.16857e+07	58932.7	1.15351e+07	1.17776e+07	nan         	176            	112.38    	230       	0.0011816     	0.0721178
# 15 	54     	1.1672e+07 	65534.1	1.15108e+07	1.17817e+07	nan         	210            	129.12    	351       	0.00121641    	0.0782852
# 16 	62     	1.16711e+07	64545.7	1.14469e+07	1.17776e+07	nan         	249            	153.155   	365       	0.0010283     	0.0753555
# 17 	66     	1.16619e+07	66077.2	1.14317e+07	1.17817e+07	nan         	289            	178.685   	428       	0.00104117    	0.0838904
# 18 	57     	1.1645e+07 	80462.6	1.14317e+07	1.17867e+07	nan         	289            	188.255   	489       	0.00116062    	0.100747
# 19 	70     	1.16395e+07	84313.8	1.14317e+07	1.17776e+07	nan         	289            	195.975   	529       	0.0010848     	0.0932255
# 20 	69     	1.16468e+07	76791  	1.14317e+07	1.17822e+07	nan         	289            	215.98    	584       	0.000989914   	0.0939393
# Best individual:
#  x[0]*x[0]/(x[0]+ε)+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]*x[0]+x[0]+x[0]+x[0]+x
# [0]/(x[0]+ε)+x[0]/(x[0]+ε)+x[0]/(x[0]+ε)+x[0]/(x[0]+ε)+x[0]+x[0]*x[0]+x[0]+x[0]+
# x[0]+x[0]+x[0]*x[0]+x[0]*0+x[0]+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]+x[0]+x[0]*x[0]
# +x[0]*x[0]*x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]/(x[0]+ε)+x[0]/(x[0]+
# ε)+x[0]*x[0]/(x[0]+ε)+x[0]+x[0]*x[0]*x[0]+x[0]/(x[0]+ε)/(x[0]+ε)+x[0]+x[0]+x[0]+
# x[0]+x[0]+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]+x[0]/(x[0]+ε)+x[0]/(x[0]+ε)+x[0]+x[0
# ]+x[0]-x[0]+x[0]+x[0]*x[0]/(x[0]+ε)+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)*x[0]/
# (x[0]+ε)+x[0]+x[0]+x[0]+x[0]*x[0]+x[0]+x[0]+x[0]+x[0]*x[0]/(x[0]+ε)+x[0]+x[0]*x[
# 0]+x[0]+x[0]+x[0]+x[0]
#
# Training Fitness:  11431684.034703622
# Depth:  16
# Length of the genome:  289
# Used portion of the genome: 0.82
#
#
# Currently on run 5 of 32
# gen	invalid	avg        	std    	min        	max        	fitness_test	best_ind_length	avg_length	max_length	selection_time	generation_time
# 0  	0      	1.17819e+07	4734.48	1.17677e+07	1.17959e+07	8.42461e+06 	22             	8.285     	22        	0             	0.0139086
# 1  	62     	1.17802e+07	4073.63	1.17677e+07	1.17867e+07	8.42461e+06 	22             	8.91      	32        	0.00238943    	0.0591981
# 2  	48     	1.17779e+07	4592   	1.1764e+07 	1.17876e+07	nan         	21             	12.125    	32        	0.00106907    	0.0318184
# 3  	30     	1.17747e+07	5457.55	1.1755e+07 	1.17867e+07	nan         	27             	15.435    	39        	0.00105691    	0.0274129
# 4  	30     	1.1771e+07 	6562.12	1.17544e+07	1.17826e+07	nan         	36             	19.575    	41        	0.00108314    	0.0273175
# 5  	38     	1.17667e+07	9211.87	1.17373e+07	1.17872e+07	nan         	40             	24.17     	48        	0.00181341    	0.0302672
# 6  	23     	1.17601e+07	11977  	1.17152e+07	1.17872e+07	nan         	51             	30.485    	62        	0.00170255    	0.0398891
# 7  	23     	1.17536e+07	18175  	1.16883e+07	1.17872e+07	nan         	86             	37.205    	86        	0.00102997    	0.0416741
# 8  	20     	1.17435e+07	23527  	1.16768e+07	1.17867e+07	nan         	84             	46.585    	112       	0.00146699    	0.041446
# 9  	10     	1.17305e+07	28339.2	1.16495e+07	1.17826e+07	nan         	104            	57.835    	131       	0.000901222   	0.0461698
# 10 	31     	1.17195e+07	34667.2	1.16285e+07	1.17831e+07	nan         	111            	69.01     	164       	0.000870466   	0.0533981
# 11 	25     	1.17062e+07	45219  	1.15944e+07	1.17867e+07	nan         	141            	80.495    	153       	0.00139618    	0.0612504
# 12 	31     	1.16942e+07	49925  	1.1555e+07 	1.17826e+07	nan         	192            	94.12     	193       	0.00136161    	0.0647264
# 13 	39     	1.16768e+07	61796.8	1.1478e+07 	1.17872e+07	nan         	189            	115.515   	251       	0.00146532    	0.078486
# 14 	57     	1.16684e+07	67229.5	1.1478e+07 	1.17826e+07	nan         	189            	130.675   	294       	0.000948191   	0.0716422
# 15 	50     	1.16659e+07	73734.9	1.14649e+07	1.17826e+07	nan         	226            	139.59    	328       	0.00101662    	0.0716381
# 16 	59     	1.16553e+07	72166.9	1.14649e+07	1.17872e+07	nan         	226            	161.985   	438       	0.000995398   	0.0770166
# 17 	56     	1.16545e+07	70199  	1.14572e+07	1.17826e+07	nan         	330            	200.09    	452       	0.000949383   	0.0871143
# 18 	63     	1.16374e+07	75866.2	1.14325e+07	1.17826e+07	nan         	306            	202.19    	474       	0.00161457    	0.0962179
# 19 	56     	1.16295e+07	88536.4	1.13916e+07	1.17826e+07	nan         	254            	224.875   	494       	0.000973701   	0.0962901
# 20 	81     	1.16317e+07	82224.3	1.13916e+07	1.17822e+07	nan         	254            	240.09    	562       	0.0010674     	0.103119
# Best individual:
#  x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]-x[0]+x[0]+
# x[0]+x[0]+x[0]+x[0]+0/(x[0]+ε)*x[0]+0/(x[0]+ε)+x[0]*x[0]+x[0]+x[0]+x[0]+x[0]-x[0
# ]+x[0]+x[0]/(x[0]+ε)+x[0]+x[0]+x[0]+x[0]*x[0]+x[0]+x[0]+x[0]*x[0]+1+x[0]+x[0]+x[
# 0]+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+0+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+x[
# 0]+x[0]+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)*x[0]/(x[0]+ε)+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]
# +x[0]+x[0]+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)*x[0]+x[0]*x[0]*x[0]+x[0]-x[0]+x[0]+x[0]+
# x[0]+x[0]+x[0]+0/(x[0]+ε)+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+
# x[0]+x[0]*x[0]+x[0]+x[0]+x[0]+x[0]+x[0]-x[0]+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)
#
# Training Fitness:  11391639.775047008
# Depth:  17
# Length of the genome:  254
# Used portion of the genome: 0.97
#
#
# Currently on run 6 of 32
# gen	invalid	avg        	std 	min       	max     	fitness_test	best_ind_length	avg_length	max_length	selection_time	generation_time
# 0  	0      	1.17825e+07	4512	1.1764e+07	1.18e+07	nan         	19             	8.315     	22        	0             	0.00611401
# 1  	64     	1.17804e+07	4380.28	1.1764e+07	1.17917e+07	nan         	19             	8.71      	28        	0.000915766   	0.0541937
# 2  	38     	1.17783e+07	5249.09	1.17636e+07	1.17917e+07	nan         	16             	11.35     	32        	0.00093627    	0.0230134
# 3  	29     	1.17745e+07	6337.9 	1.17462e+07	1.17872e+07	nan         	35             	14        	44        	0.00104094    	0.0315709
# 4  	30     	1.17699e+07	7464.96	1.17454e+07	1.17867e+07	nan         	30             	18.34     	49        	0.00111365    	0.0289407
# 5  	22     	1.17658e+07	10347.5	1.17331e+07	1.17867e+07	nan         	43             	22.12     	63        	0.000983238   	0.0312295
# 6  	23     	1.17595e+07	13947  	1.1717e+07 	1.17867e+07	nan         	60             	28.65     	69        	0.00165153    	0.0298569
# 7  	22     	1.17524e+07	16593.5	1.17044e+07	1.17826e+07	8.42461e+06 	53             	35.49     	77        	0.000979185   	0.039274
# 8  	22     	1.17413e+07	21724.3	1.16853e+07	1.17867e+07	nan         	81             	42.105    	91        	0.000901461   	0.0447526
# 9  	37     	1.17311e+07	25164.6	1.16464e+07	1.17817e+07	nan         	94             	50.385    	106       	0.000953197   	0.0441701
# 10 	27     	1.17223e+07	35409.6	1.16328e+07	1.17867e+07	nan         	129            	63.195    	148       	0.00110745    	0.0602224
# 11 	30     	1.17042e+07	36887.6	1.16095e+07	1.17822e+07	nan         	118            	77.47     	195       	0.000957489   	0.0558825
# 12 	36     	1.16929e+07	43647.7	1.1578e+07 	1.17822e+07	nan         	138            	93.64     	220       	0.00101805    	0.0656679
# 13 	56     	1.16834e+07	58176  	1.15489e+07	1.17867e+07	nan         	160            	113.255   	257       	0.00101948    	0.0642805
# 14 	50     	1.16525e+07	63091.9	1.14565e+07	1.17817e+07	nan         	229            	138.915   	268       	0.00103045    	0.0978804
# 15 	65     	1.16542e+07	72116.4	1.1439e+07 	1.17867e+07	nan         	280            	159.325   	313       	0.00115275    	0.158412
# 16 	60     	1.16424e+07	82533.4	1.14187e+07	1.17822e+07	nan         	279            	183.78    	419       	0.00182366    	0.0947411
# 17 	68     	1.16313e+07	85551.3	1.13019e+07	1.17867e+07	nan         	302            	205.955   	458       	0.000941038   	0.0951731
# 18 	69     	1.1616e+07 	92155.1	1.13019e+07	1.17822e+07	nan         	302            	237.99    	528       	0.00100684    	0.114535
# 19 	85     	1.15967e+07	94652  	1.13019e+07	1.17822e+07	nan         	302            	259.99    	603       	0.00118041    	0.113239
# 20 	91     	1.16053e+07	105064 	1.13019e+07	1.17767e+07	nan         	302            	294.705   	657       	0.00110841    	0.111501
# Best individual:
#  x[0]+x[0]/(x[0]+ε)+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]*x
# [0]+x[0]*x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x
# [0]+x[0]+x[0]+1+x[0]/(x[0]+ε)+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)*x[0]+x[0]+x[0]+x[0]/(
# x[0]+ε)+x[0]+x[0]+x[0]+x[0]+x[0]-x[0]+x[0]+x[0]/(x[0]+ε)+x[0]+x[0]+x[0]+x[0]+x[0
# ]+x[0]+x[0]*x[0]+x[0]/(x[0]+ε)/(x[0]+ε)*x[0]+x[0]+x[0]+x[0]+x[0]+x[0]*x[0]+x[0]+
# x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]*x[0]+x[0]+x[0]+x[0]+x[0]+x[0]*x[0]/(x[0]+ε)/(
# x[0]+ε)+x[0]*x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]/(x[0]+ε)
# +x[0]+x[0]+x[0]*x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]*
# x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]+x
# [0]*x[0]+x[0]/(x[0]+ε)
#
# Training Fitness:  11301886.346133936
# Depth:  17
# Length of the genome:  302
# Used portion of the genome: 0.91
#
#
# Currently on run 7 of 32
# gen	invalid	avg        	std    	min        	max        	fitness_test	best_ind_length	avg_length	max_length	selection_time	generation_time
# 0  	0      	1.17827e+07	4996.55	1.17636e+07	1.17967e+07	8.42461e+06 	21             	8.445     	22        	0             	0.00694156
# 1  	64     	1.17797e+07	4790.95	1.17636e+07	1.17917e+07	8.42461e+06 	21             	8.48      	28        	0.00101614    	0.0574036
# 2  	40     	1.17774e+07	5242.59	1.1759e+07 	1.17867e+07	8.42461e+06 	16             	11.75     	33        	0.00110221    	0.0275102
# 3  	39     	1.17739e+07	6940.35	1.17545e+07	1.17867e+07	8.42461e+06 	38             	15.19     	41        	0.00104833    	0.0319071
# 4  	31     	1.17691e+07	8595.73	1.17454e+07	1.17872e+07	nan         	38             	20.155    	43        	0.00110602    	0.026762
# 5  	46     	1.17651e+07	10564.7	1.17346e+07	1.17867e+07	8.42461e+06 	44             	24.08     	47        	0.0017488     	0.0293288
# 6  	22     	1.17591e+07	12716.7	1.17125e+07	1.17867e+07	8.42461e+06 	56             	28.55     	57        	0.00134444    	0.0343037
# 7  	21     	1.17503e+07	16388.9	1.17003e+07	1.17826e+07	nan         	65             	35.085    	78        	0.00107956    	0.0381441
# 8  	26     	1.17393e+07	19520.3	1.16895e+07	1.17822e+07	8.42461e+06 	71             	43.93     	95        	0.00224018    	0.0507154
# 9  	32     	1.17298e+07	24710.2	1.16719e+07	1.17776e+07	nan         	93             	53.07     	98        	0.00105977    	0.0451958
# 10 	29     	1.17225e+07	26931.6	1.16544e+07	1.17867e+07	nan         	106            	61.78     	140       	0.00104737    	0.0522718
# 11 	42     	1.17147e+07	36303.3	1.15865e+07	1.17867e+07	nan         	157            	73.47     	186       	0.0022769     	0.0584099
# 12 	43     	1.17073e+07	44753.2	1.15267e+07	1.17822e+07	nan         	206            	90.035    	225       	0.00102711    	0.0662947
# 13 	43     	1.16897e+07	56930.7	1.15041e+07	1.17822e+07	nan         	275            	103.345   	275       	0.00111771    	0.0714355
# 14 	44     	1.16673e+07	60820.7	1.14845e+07	1.17822e+07	nan         	253            	120.9     	282       	0.00106502    	0.0852139
# 15 	58     	1.16517e+07	69946.5	1.14845e+07	1.17822e+07	nan         	253            	149.195   	384       	0.00106692    	0.0926523
# 16 	60     	1.16474e+07	74963  	1.13954e+07	1.17867e+07	nan         	460            	171.135   	460       	0.00104237    	0.0887582
# 17 	70     	1.16319e+07	81704.3	1.1354e+07 	1.17867e+07	nan         	368            	197.395   	473       	0.00102949    	0.117445
# 18 	77     	1.16139e+07	87903.5	1.1354e+07 	1.17822e+07	nan         	368            	211.59    	582       	0.00104499    	0.122485
# 19 	81     	1.16099e+07	102349 	1.13002e+07	1.17776e+07	nan         	433            	261.735   	679       	0.00127888    	0.128277
# 20 	72     	1.16077e+07	103509 	1.12144e+07	1.17822e+07	nan         	441            	311.935   	647       	0.00136375    	0.142157
# Best individual:
#  x[0]+x[0]+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)-x[0]*x[0]+x[0]+x[0]*x[0]*x[0]+x[0]+x[0]+1
# *x[0]+x[0]+x[0]/(x[0]+ε)+x[0]+x[0]+x[0]-x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+0+x[0
# ]+x[0]+x[0]+1+x[0]-0+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]*x[0]+x[0]-0+x[0]*x[0]*0+
# x[0]*x[0]*x[0]+0+x[0]+x[0]*0+x[0]+0+x[0]+x[0]+x[0]+x[0]+x[0]-x[0]+0+x[0]+x[0]/1+
# x[0]+x[0]*x[0]/(x[0]+ε)+x[0]+x[0]+x[0]-x[0]+x[0]+x[0]+0+x[0]+x[0]+0+x[0]+x[0]+x[
# 0]+1+x[0]-0+x[0]+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)*x[0]+x[0]-x[0]+x[0]+x[0]+x[0]+x[0]
# +x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]/1+x[0]-x[0]+x[0]+x[0]+x[0]/(x
# [0]+ε)+x[0]+x[0]+x[0]*x[0]/(x[0]+ε)+0-x[0]*x[0]+0+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+
# x[0]+x[0]+x[0]*x[0]+x[0]+0+x[0]*x[0]+x[0]+x[0]/(x[0]+ε)+x[0]+x[0]/(x[0]+ε)+x[0]+
# x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+1+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]*x[0]+0+x[0]+0+
# x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]*x[0]*x[0]*x[0]*x[0]+x[0]*x[0]/
# (x[0]+ε)+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+0+x[0]+x[0]+x[0]+0+x[0]*x[0]+x[0]
#
# Training Fitness:  11214362.748888355
# Depth:  17
# Length of the genome:  441
# Used portion of the genome: 0.95
#
#
# Currently on run 8 of 32
# gen	invalid	avg        	std    	min        	max        	fitness_test	best_ind_length	avg_length	max_length	selection_time	generation_time
# 0  	0      	1.17832e+07	4808.15	1.17599e+07	1.18008e+07	nan         	19             	8.225     	22        	0             	0.0115709
# 1  	63     	1.17807e+07	5454.83	1.17599e+07	1.17958e+07	nan         	19             	8.265     	33        	0.00115657    	0.0492165
# 2  	38     	1.17777e+07	6863.72	1.17508e+07	1.17909e+07	nan         	22             	10.88     	40        	0.00147247    	0.0268047
# 3  	32     	1.17731e+07	8688.89	1.17508e+07	1.17867e+07	nan         	22             	14.63     	40        	0.00218034    	0.0323567
# 4  	36     	1.17659e+07	9400.33	1.17418e+07	1.17831e+07	nan         	28             	18.57     	40        	0.00139785    	0.0269716
# 5  	25     	1.17597e+07	12243.6	1.17282e+07	1.17867e+07	nan         	34             	22.25     	48        	0.00109506    	0.0305758
# 6  	34     	1.17524e+07	15966.5	1.17012e+07	1.17826e+07	nan         	44             	27.365    	66        	0.00151968    	0.0368409
# 7  	26     	1.17432e+07	20404.9	1.16832e+07	1.17867e+07	nan         	54             	34.045    	71        	0.00130868    	0.0379412
# 8  	22     	1.17299e+07	25932.6	1.16468e+07	1.17867e+07	nan         	83             	43.19     	91        	0.00106835    	0.0421839
# 9  	28     	1.17165e+07	35196.5	1.16241e+07	1.17922e+07	nan         	87             	55.26     	123       	0.00174141    	0.0505767
# 10 	32     	1.17035e+07	41581  	1.15663e+07	1.17822e+07	nan         	113            	70.11     	159       	0.00270915    	0.0624037
# 11 	51     	1.16886e+07	46301.7	1.15622e+07	1.17817e+07	nan         	115            	78.35     	165       	0.00149965    	0.0695989
# 12 	54     	1.16827e+07	54034.4	1.15053e+07	1.17822e+07	nan         	142            	90.745    	212       	0.0011611     	0.0626593
# 13 	66     	1.16773e+07	59245.1	1.15045e+07	1.17826e+07	nan         	142            	102.52    	227       	0.0012784     	0.0652797
# 14 	56     	1.16551e+07	61711.5	1.14992e+07	1.17826e+07	nan         	152            	125.105   	287       	0.00145221    	0.0948071
# 15 	74     	1.1656e+07 	70477.8	1.14388e+07	1.17867e+07	nan         	180            	132.065   	323       	0.00122643    	0.0924118
# 16 	67     	1.16508e+07	81139.7	1.14143e+07	1.1783e+07 	nan         	223            	139.42    	296       	0.001086      	0.0852513
# 17 	67     	1.16372e+07	87185.3	1.14129e+07	1.17822e+07	nan         	288            	161.06    	335       	0.00112081    	0.104719
# 18 	58     	1.16283e+07	84089.1	1.13379e+07	1.17772e+07	nan         	272            	184.75    	382       	0.00211072    	0.0951252
# 19 	68     	1.16341e+07	83967.9	1.13379e+07	1.17867e+07	nan         	272            	192.79    	503       	0.0010829     	0.0931931
# 20 	68     	1.16221e+07	90898.2	1.13262e+07	1.17772e+07	nan         	374            	224.765   	543       	0.00114655    	0.104773
# Best individual:
#  x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+
# x[0]*x[0]/(x[0]+ε)+x[0]+x[0]+0+x[0]+x[0]/(x[0]+ε)+x[0]*x[0]+x[0]+x[0]+x[0]+x[0]+
# x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]*x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+0*x[0]-x[0
# ]+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)*
# x[0]+x[0]+x[0]+0+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]+x[0]*x[0]+x[0]+x[0]+x[0]/(x[0
# ]+ε)+x[0]+x[0]+x[0]*x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+
# x[0]+x[0]+x[0]+x[0]+x[0]+x[0]-x[0]-x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+
# x[0]+x[0]*x[0]+0/(x[0]+ε)+x[0]+x[0]-x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]*x[0]
# +x[0]+x[0]/(x[0]+ε)+x[0]+x[0]+x[0]+x[0]+x[0]
#
# Training Fitness:  11326179.767185837
# Depth:  16
# Length of the genome:  374
# Used portion of the genome: 0.72
#
#
# Currently on run 9 of 32
# gen	invalid	avg       	std    	min        	max        	fitness_test	best_ind_length	avg_length	max_length	selection_time	generation_time
# 0  	0      	1.1783e+07	4508.04	1.17722e+07	1.18019e+07	nan         	19             	8.455     	22        	0             	0.00744748
# 1  	50     	1.17796e+07	3996.1 	1.17677e+07	1.17913e+07	8.42461e+06 	14             	8.62      	26        	0.00108624    	0.0528402
# 2  	47     	1.17768e+07	4153.31	1.17677e+07	1.17879e+07	8.42461e+06 	14             	10.04     	32        	0.00114441    	0.0240149
# 3  	34     	1.17743e+07	4625.89	1.17631e+07	1.17867e+07	nan         	25             	13.24     	35        	0.00116301    	0.023469
# 4  	23     	1.17706e+07	5448.94	1.1754e+07 	1.1783e+07 	nan         	21             	16.58     	38        	0.00110221    	0.0274456
# 5  	25     	1.17661e+07	7424.39	1.1745e+07 	1.17822e+07	nan         	30             	19.745    	52        	0.00113106    	0.0295575
# 6  	19     	1.17614e+07	10358.2	1.17323e+07	1.17826e+07	nan         	37             	23.81     	51        	0.00116563    	0.0354722
# 7  	10     	1.17539e+07	14256.6	1.16903e+07	1.17812e+07	nan         	70             	29.025    	70        	0.00171423    	0.0426478
# 8  	24     	1.17452e+07	19355.8	1.16903e+07	1.17781e+07	nan         	70             	36.13     	84        	0.00146508    	0.0387423
# 9  	22     	1.17332e+07	23805.1	1.16679e+07	1.17817e+07	nan         	69             	45.15     	95        	0.00108242    	0.0449634
# 10 	33     	1.17234e+07	30940.4	1.16369e+07	1.17826e+07	nan         	119            	56.08     	119       	0.00105071    	0.0501344
# 11 	46     	1.1717e+07 	34281.2	1.16258e+07	1.17867e+07	nan         	133            	66.87     	134       	0.00103712    	0.0537827
# 12 	34     	1.17111e+07	40428.4	1.16066e+07	1.17822e+07	nan         	134            	75.75     	177       	0.00113583    	0.066577
# 13 	41     	1.17026e+07	45272.3	1.15781e+07	1.17822e+07	nan         	168            	90.285    	226       	0.00110149    	0.0646043
# 14 	47     	1.16988e+07	50056.5	1.1544e+07 	1.17781e+07	nan         	146            	102.525   	231       	0.00111294    	0.0780678
# 15 	39     	1.16801e+07	48978.7	1.1544e+07 	1.17776e+07	nan         	146            	120.22    	298       	0.00240803    	0.0816119
# 16 	64     	1.1675e+07 	66305.6	1.14603e+07	1.17867e+07	nan         	275            	137.915   	309       	0.00109553    	0.0977199
# 17 	64     	1.16578e+07	72579.5	1.14603e+07	1.17867e+07	nan         	275            	152.41    	333       	0.00111532    	0.0956194
# 18 	57     	1.16527e+07	77068.4	1.14479e+07	1.17867e+07	nan         	397            	170.625   	397       	0.00121665    	0.110633
# 19 	59     	1.16635e+07	76927.7	1.14024e+07	1.17867e+07	nan         	381            	184.7     	397       	0.00187349    	0.100549
# 20 	56     	1.16564e+07	82363.2	1.13748e+07	1.17772e+07	nan         	251            	208.845   	443       	0.00126195    	0.111943
# Best individual:
#  x[0]*x[0]+x[0]+x[0]*x[0]*x[0]+x[0]+x[0]+x[0]+0+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)*x[0]
# +x[0]+x[0]+x[0]+x[0]*x[0]*x[0]+x[0]+x[0]+x[0]+x[0]+0-x[0]*x[0]+x[0]*x[0]+x[0]+x[
# 0]+x[0]+x[0]+x[0]+x[0]+0+x[0]/(x[0]+ε)+x[0]*x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x
# [0]+x[0]+x[0]+x[0]+x[0]*x[0]+x[0]+x[0]+x[0]+x[0]+x[0]-x[0]+x[0]+x[0]+x[0]+x[0]+x
# [0]*x[0]/(x[0]+ε)+x[0]*x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[
# 0]+x[0]*x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+1+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]-x[0]+
# x[0]*x[0]*x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+1+x[0]*x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0
# ]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]
#
# Training Fitness:  11374791.168995544
# Depth:  15
# Length of the genome:  251
# Used portion of the genome: 0.98
#
#
# Currently on run 10 of 32
# gen	invalid	avg        	std    	min        	max        	fitness_test	best_ind_length	avg_length	max_length	selection_time	generation_time
# 0  	0      	1.17821e+07	4788.82	1.17594e+07	1.18004e+07	nan         	22             	8.375     	22        	0             	0.0140772
# 1  	62     	1.17801e+07	4846.72	1.17594e+07	1.17958e+07	nan         	22             	9.435     	32        	0.00111604    	0.05709
# 2  	52     	1.17772e+07	5200.98	1.17594e+07	1.17917e+07	nan         	22             	11.66     	25        	0.00112486    	0.0302689
# 3  	35     	1.17734e+07	5953.42	1.17589e+07	1.17867e+07	nan         	24             	15.13     	34        	0.00131345    	0.0275102
# 4  	18     	1.17695e+07	6348.73	1.17499e+07	1.17867e+07	nan         	36             	18.87     	45        	0.00153708    	0.0328169
# 5  	23     	1.17663e+07	7542.63	1.17373e+07	1.17867e+07	nan         	35             	20.555    	50        	0.00163507    	0.0397062
# 6  	29     	1.17617e+07	10045.2	1.17231e+07	1.17822e+07	nan         	58             	23.785    	62        	0.00132251    	0.0356221
# 7  	18     	1.17563e+07	13258.1	1.17096e+07	1.17867e+07	nan         	69             	29.65     	76        	0.00122309    	0.0390811
# 8  	27     	1.17519e+07	15830.1	1.17047e+07	1.17867e+07	nan         	66             	34.205    	75        	0.00221419    	0.0465534
# 9  	27     	1.1745e+07 	19580.5	1.16659e+07	1.17867e+07	nan         	88             	40.415    	91        	0.0016396     	0.0432987
# 10 	31     	1.1734e+07 	24979.8	1.16542e+07	1.17776e+07	nan         	94             	50.505    	130       	0.00128865    	0.0510738
# 11 	39     	1.1726e+07 	29724.1	1.16542e+07	1.17781e+07	nan         	94             	60.765    	141       	0.00116611    	0.0630107
# 12 	33     	1.17187e+07	33048.9	1.16309e+07	1.17867e+07	nan         	122            	73.52     	182       	0.0012722     	0.0636435
# 13 	44     	1.17118e+07	36726.5	1.16105e+07	1.17776e+07	nan         	157            	84.535    	192       	0.00116086    	0.0687292
# 14 	43     	1.17021e+07	42708.4	1.15944e+07	1.17822e+07	nan         	135            	102.745   	266       	0.0011425     	0.0775139
# 15 	36     	1.1683e+07 	52754.6	1.15468e+07	1.17781e+07	nan         	220            	120.795   	277       	0.00105977    	0.0774686
# 16 	58     	1.16763e+07	54376.3	1.1538e+07 	1.17776e+07	nan         	220            	140.335   	302       	0.00152993    	0.0924728
# 17 	58     	1.16706e+07	61175.2	1.14604e+07	1.17867e+07	nan         	280            	169.01    	370       	0.0019927     	0.118822
# 18 	64     	1.16658e+07	65905.4	1.14176e+07	1.17822e+07	nan         	350            	192.97    	432       	0.00298905    	0.269672
# 19 	74     	1.16723e+07	70521.4	1.14176e+07	1.17776e+07	nan         	350            	187.265   	485       	0.00223446    	0.142688
# 20 	63     	1.16604e+07	74331  	1.14176e+07	1.17776e+07	nan         	350            	217.085   	524       	0.00125957    	0.132539
# Best individual:
#  x[0]+x[0]*x[0]+x[0]/(x[0]+ε)+x[0]+x[0]-x[0]/(x[0]+ε)+x[0]*x[0]+x[0]+x[0]+x[0]/(x
# [0]+ε)-x[0]+x[0]/(x[0]+ε)/(x[0]+ε)+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]*1+x[0]+x[0]
# /(x[0]+ε)+x[0]+x[0]-x[0]*x[0]-x[0]+x[0]+x[0]+x[0]+x[0]*x[0]/(x[0]+ε)+x[0]*x[0]+x
# [0]+x[0]+x[0]+x[0]+0*x[0]+x[0]/(x[0]+ε)*x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]+0+x[0]
# +x[0]-x[0]+x[0]*0+x[0]+0+x[0]+x[0]/(x[0]+ε)/(x[0]+ε)+x[0]+x[0]/(x[0]+ε)+x[0]*x[0
# ]+x[0]+x[0]+x[0]+x[0]+x[0]*1+x[0]+x[0]-x[0]+x[0]*x[0]+x[0]+x[0]+x[0]+x[0]/(x[0]+
# ε)+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]/(x[0]+ε)+
# x[0]*0+x[0]+x[0]+x[0]+x[0]+x[0]*x[0]+x[0]-x[0]+x[0]/(x[0]+ε)/(x[0]+ε)+x[0]*x[0]+
# x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+0*x[0]+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]/(x[0]+ε)+
# x[0]+x[0]/(x[0]+ε)+x[0]+x[0]+x[0]*0+x[0]+x[0]+x[0]-x[0]+x[0]+x[0]+x[0]
#
# Training Fitness:  11417616.642991457
# Depth:  17
# Length of the genome:  350
# Used portion of the genome: 0.86
#
#
# Currently on run 11 of 32
# gen	invalid	avg        	std    	min        	max     	fitness_test	best_ind_length	avg_length	max_length	selection_time	generation_time
# 0  	0      	1.17828e+07	4572.46	1.17644e+07	1.18e+07	nan         	22             	8.525     	22        	0             	0.0199611
# 1  	68     	1.17806e+07	4443.52	1.17644e+07	1.1793e+07	nan         	22             	9.665     	33        	0.00286245    	0.098001
# 2  	41     	1.17778e+07	4929.9 	1.1764e+07 	1.17872e+07	8.42461e+06 	18             	12.085    	36        	0.00124931    	0.028353
# 3  	43     	1.17744e+07	5755.98	1.17463e+07	1.17867e+07	nan         	37             	14.865    	38        	0.00123835    	0.0315008
# 4  	24     	1.17711e+07	6206.66	1.17463e+07	1.17867e+07	nan         	37             	17.325    	41        	0.00121069    	0.024811
# 5  	24     	1.17672e+07	7936.78	1.17286e+07	1.17826e+07	nan         	50             	20.56     	50        	0.0013442     	0.0266037
# 6  	17     	1.1763e+07 	11116.2	1.172e+07  	1.17867e+07	nan         	53             	24.065    	68        	0.00111222    	0.0305028
# 7  	25     	1.17574e+07	13973  	1.17024e+07	1.17867e+07	nan         	66             	29.36     	71        	0.00110674    	0.0327892
# 8  	27     	1.17493e+07	18384.1	1.1688e+07 	1.17867e+07	nan         	68             	35.825    	73        	0.00113249    	0.0370817
# 9  	29     	1.17404e+07	22568.9	1.16479e+07	1.17822e+07	nan         	87             	43.715    	103       	0.00148988    	0.0430899
# 10 	33     	1.17308e+07	27727.1	1.16479e+07	1.17913e+07	nan         	87             	54.095    	110       	0.00147557    	0.0543933
# 11 	38     	1.17227e+07	33596.3	1.15968e+07	1.17871e+07	nan         	122            	60.445    	139       	0.0012753     	0.0525651
# 12 	31     	1.17083e+07	42438.9	1.15523e+07	1.17867e+07	nan         	147            	75.695    	185       	0.00113034    	0.0585434
# 13 	45     	1.16984e+07	47715.9	1.15523e+07	1.17822e+07	nan         	147            	93.225    	263       	0.00113797    	0.062007
# 14 	41     	1.16884e+07	57396.4	1.14452e+07	1.17822e+07	nan         	277            	106.6     	277       	0.0011251     	0.0667198
# 15 	51     	1.16751e+07	78830.6	1.14174e+07	1.17867e+07	nan         	208            	126.165   	288       	0.00109744    	0.0875816
# 16 	68     	1.16642e+07	81506.5	1.13964e+07	1.17776e+07	nan         	307            	152.53    	356       	0.00129175    	0.0947237
# 17 	50     	1.16473e+07	84833.2	1.13731e+07	1.17867e+07	nan         	268            	167.465   	397       	0.00117087    	0.0907233
# 18 	65     	1.16478e+07	93064.5	1.13731e+07	1.17867e+07	nan         	268            	165.08    	343       	0.00112724    	0.0918119
# 19 	64     	1.16555e+07	81334.5	1.13731e+07	1.17867e+07	nan         	268            	180.79    	458       	0.00159478    	0.0964978
# 20 	65     	1.16575e+07	84170.2	1.13731e+07	1.17867e+07	nan         	268            	199.695   	529       	0.00115013    	0.10584
# Best individual:
#  x[0]+x[0]/(x[0]+ε)+x[0]+x[0]/(x[0]+ε)-x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]/(x[0]+ε
# )/(x[0]+ε)+x[0]+x[0]*x[0]+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]+x[0]+x[0]+x[0]+x[0]+
# x[0]+x[0]/(x[0]+ε)+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]+x[0]/(x[0]+ε)+x[0]+x[0]/(x[0]+ε)
# +x[0]+x[0]+x[0]/(x[0]+ε)/(x[0]+ε)+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]/(x[0]+
# ε)+x[0]+x[0]+x[0]+1+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]+x[0]+x[0]+x
# [0]-x[0]+x[0]*x[0]+x[0]/(x[0]+ε)+x[0]+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]+x[0]/(x[
# 0]+ε)+x[0]+x[0]+x[0]/(x[0]+ε)/(x[0]+ε)+x[0]+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]+x[
# 0]+x[0]-x[0]+x[0]/(x[0]+ε)/(x[0]+ε)+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]*x[0]+x[0]*x[0]
# +x[0]+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)/(x[0]+ε)+x[0]+x[0]+x[0]*x[0]+x[0]+x[0]/(x[0]+
# ε)+x[0]+x[0]+x[0]+x[0]
#
# Training Fitness:  11373052.31065225
# Depth:  17
# Length of the genome:  268
# Used portion of the genome: 0.97
#
#
# Currently on run 12 of 32
# gen	invalid	avg        	std   	min       	max        	fitness_test	best_ind_length	avg_length	max_length	selection_time	generation_time
# 0  	0      	1.17827e+07	4836.2	1.1764e+07	1.18042e+07	8.42461e+06 	18             	8.37      	22        	0             	0.0122321
# 1  	69     	1.17807e+07	4710.29	1.1764e+07	1.17913e+07	8.42461e+06 	18             	9.305     	30        	0.00117445    	0.0614438
# 2  	44     	1.17781e+07	4940.25	1.1764e+07	1.17867e+07	8.42461e+06 	18             	12.76     	33        	0.00103474    	0.0246818
# 3  	32     	1.17746e+07	6195.91	1.17566e+07	1.17917e+07	nan         	34             	17.155    	46        	0.00110054    	0.0268848
# 4  	26     	1.17714e+07	7822.81	1.17471e+07	1.17867e+07	nan         	36             	20.41     	45        	0.00118661    	0.0493524
# 5  	21     	1.17675e+07	9494.47	1.1743e+07 	1.17867e+07	nan         	39             	25.155    	56        	0.00129557    	0.0458605
# 6  	20     	1.17629e+07	11816.3	1.17249e+07	1.17913e+07	nan         	44             	30.81     	66        	0.00107479    	0.0395193
# 7  	20     	1.17561e+07	16546.4	1.17032e+07	1.17867e+07	nan         	65             	35.76     	77        	0.00231099    	0.0582876
# ...
# 0]+x[0]+x[0]*x[0]+x[0]+x[0]-x[0]+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]*x[0]+x[0]+x[0
# ]+0+x[0]*x[0]+x[0]+x[0]+x[0]+x[0]+x[0]*x[0]+x[0]+x[0]+x[0]+x[0]+x[0]-x[0]+x[0]+x
# [0]+x[0]+x[0]*x[0]+x[0]+x[0]*x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]*x[0]+x
# [0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]*x[0]
#
# Training Fitness:  11298418.302797707
# Depth:  17
# Length of the genome:  290
# Used portion of the genome: 0.97
#
#
# Currently on run 28 of 32
# gen	invalid	avg        	std    	min        	max     	fitness_test	best_ind_length	avg_length	max_length	selection_time	generation_time
# 0  	0      	1.17827e+07	5021.69	1.17681e+07	1.18e+07	nan         	19             	8.235     	22        	0             	0.00777555
# 1  	71     	1.17807e+07	3687.21	1.17681e+07	1.17917e+07	nan         	19             	8.965     	26        	0.00111914    	0.0691929
# 2  	34     	1.17784e+07	4512.64	1.17681e+07	1.17955e+07	nan         	19             	11.915    	31        	0.0015738     	0.0325286
# 3  	32     	1.17749e+07	5050.04	1.17554e+07	1.17867e+07	nan         	29             	14.36     	29        	0.00118232    	0.0277731
# 4  	30     	1.17727e+07	5623.46	1.17554e+07	1.17872e+07	nan         	29             	17.74     	38        	0.0012002     	0.0289667
# 5  	20     	1.17699e+07	6419.05	1.17463e+07	1.17872e+07	nan         	36             	20.02     	44        	0.00126886    	0.030997
# 6  	20     	1.17662e+07	6979.81	1.17405e+07	1.17822e+07	nan         	45             	24.165    	54        	0.00122857    	0.0327229
# 7  	28     	1.17621e+07	10833.1	1.17233e+07	1.17867e+07	8.42461e+06 	47             	27.72     	57        	0.00117826    	0.0389664
# 8  	21     	1.17563e+07	14889.2	1.17057e+07	1.17867e+07	nan         	60             	34.25     	78        	0.0012033     	0.0395925
# 9  	27     	1.17466e+07	20641.1	1.16868e+07	1.17822e+07	nan         	62             	41.11     	93        	0.00128055    	0.0552504
# 10 	33     	1.17389e+07	26043.6	1.16436e+07	1.17867e+07	nan         	99             	51.03     	112       	0.00126004    	0.0534678
# 11 	43     	1.17269e+07	32291.5	1.16261e+07	1.17822e+07	nan         	153            	63.31     	153       	0.00119209    	0.0565727
# 12 	49     	1.17194e+07	38150.1	1.15937e+07	1.17822e+07	nan         	153            	77.52     	177       	0.00112104    	0.0610311
# 13 	54     	1.17067e+07	46138.1	1.15505e+07	1.17822e+07	nan         	153            	92.045    	206       	0.00151134    	0.0656826
# 14 	57     	1.16948e+07	48431.5	1.15505e+07	1.17822e+07	nan         	153            	106.565   	247       	0.00162601    	0.0725858
# 15 	52     	1.1677e+07 	59536.6	1.14454e+07	1.17776e+07	nan         	236            	122.47    	306       	0.00119185    	0.0914755
# 16 	64     	1.16758e+07	71355.7	1.14454e+07	1.17822e+07	nan         	236            	146.965   	350       	0.00131512    	0.086688
# 17 	62     	1.16684e+07	77680.1	1.14454e+07	1.17822e+07	nan         	236            	175.535   	412       	0.00113297    	0.0960801
# 18 	68     	1.1654e+07 	82339.5	1.13941e+07	1.17736e+07	nan         	277            	207.55    	469       	0.00114727    	0.100423
# 19 	73     	1.1645e+07 	86478.6	1.13941e+07	1.17867e+07	nan         	277            	243.23    	540       	0.00116682    	0.108391
# 20 	78     	1.16256e+07	88616.9	1.13894e+07	1.17776e+07	nan         	431            	259.9     	660       	0.00111818    	0.128003
# Best individual:
#  x[0]+x[0]/(x[0]+ε)+x[0]-x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]-x[0]-x[0]+x[0]+x[0]+x
# [0]+x[0]+x[0]-x[0]+x[0]+x[0]+x[0]+x[0]*x[0]-x[0]+x[0]+x[0]+x[0]-x[0]+x[0]+x[0]+x
# [0]+x[0]+x[0]/(x[0]+ε)+x[0]+x[0]/(x[0]+ε)+x[0]/(x[0]+ε)+x[0]-x[0]+x[0]+x[0]+x[0]
# +x[0]+x[0]-x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]-x[0]-x[0]+x[0]
# +x[0]+x[0]+x[0]+x[0]+x[0]+1+x[0]+x[0]-x[0]+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]/(x[
# 0]+ε)+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]*x[0]+x[0]+x[0]+x[0]*x[0]*x[0]/(x[0]+ε)+x[0]+x
# [0]+x[0]+x[0]/(x[0]+ε)+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[
# 0]/(x[0]+ε)+x[0]+x[0]+x[0]-x[0]*x[0]/(x[0]+ε)+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]+
# x[0]+x[0]+x[0]+x[0]+x[0]-x[0]/(x[0]+ε)+x[0]*x[0]+x[0]+x[0]+x[0]+x[0]+x[0]-x[0]+x
# [0]-x[0]+x[0]+x[0]+x[0]
#
# Training Fitness:  11389398.788729437
# Depth:  17
# Length of the genome:  431
# Used portion of the genome: 0.65
#
#
# Currently on run 29 of 32
# gen	invalid	avg        	std    	min        	max        	fitness_test	best_ind_length	avg_length	max_length	selection_time	generation_time
# 0  	0      	1.17826e+07	4953.23	1.17644e+07	1.18018e+07	nan         	22             	8.225     	22        	0             	0.0117335
# 1  	62     	1.17806e+07	3534.53	1.17644e+07	1.17867e+07	nan         	22             	9.52      	31        	0.0011301     	0.0666184
# 2  	45     	1.1779e+07 	4214.35	1.17644e+07	1.17913e+07	nan         	22             	12.19     	32        	0.00118184    	0.0340071
# 3  	34     	1.17761e+07	5136.22	1.17558e+07	1.17913e+07	nan         	22             	15.275    	40        	0.00122452    	0.030488
# 4  	34     	1.17727e+07	6313.03	1.17504e+07	1.17835e+07	nan         	30             	17.31     	52        	0.00173235    	0.0299456
# 5  	21     	1.1768e+07 	7612.56	1.17454e+07	1.17826e+07	nan         	29             	21.47     	53        	0.00117302    	0.0353203
# 6  	24     	1.17639e+07	9822.87	1.17281e+07	1.17867e+07	nan         	59             	26.56     	60        	0.00121474    	0.0386438
# 7  	34     	1.17577e+07	12032.8	1.17236e+07	1.17826e+07	nan         	71             	32.45     	71        	0.00121832    	0.0446701
# 8  	28     	1.17527e+07	15595.4	1.17052e+07	1.17867e+07	nan         	61             	41        	84        	0.00128889    	0.0482092
# 9  	28     	1.17448e+07	20089.3	1.16885e+07	1.17826e+07	nan         	88             	48.835    	103       	0.00118279    	0.0503864
# 10 	29     	1.17356e+07	23658.3	1.16406e+07	1.17867e+07	nan         	127            	59.955    	149       	0.00118017    	0.0692708
# 11 	34     	1.1734e+07 	29917.1	1.16148e+07	1.17781e+07	nan         	134            	69.925    	150       	0.00183511    	0.0696316
# 12 	35     	1.17277e+07	30703.3	1.16148e+07	1.17785e+07	nan         	134            	77.12     	207       	0.00140309    	0.0722198
# 13 	36     	1.17204e+07	34128.4	1.16118e+07	1.17826e+07	nan         	158            	87.285    	191       	0.00123882    	0.0737002
# 14 	40     	1.17101e+07	41385.3	1.15496e+07	1.17867e+07	nan         	236            	99.99     	236       	0.00125313    	0.0829804
# 15 	42     	1.17046e+07	50196.1	1.15496e+07	1.1769e+07 	nan         	236            	116.595   	288       	0.00115299    	0.0880804
# 16 	54     	1.16961e+07	52995.9	1.15496e+07	1.17826e+07	nan         	236            	137.04    	364       	0.00122881    	0.0963495
# 17 	54     	1.16897e+07	57672.8	1.15299e+07	1.17826e+07	nan         	291            	154.21    	396       	0.00118971    	0.0956812
# 18 	44     	1.16876e+07	58132.7	1.15299e+07	1.17826e+07	nan         	291            	159.505   	455       	0.0022459     	0.27837
# 19 	54     	1.16852e+07	61967.2	1.15299e+07	1.17822e+07	nan         	291            	184.385   	471       	0.00149989    	0.144445
# 20 	58     	1.16775e+07	59972.7	1.15299e+07	1.17822e+07	nan         	291            	196.295   	474       	0.00141954    	0.166467
# Best individual:
#  x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]*x[0]/(x[0]+ε)*x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+1+x
# [0]*x[0]+x[0]+x[0]*x[0]*x[0]+x[0]/(x[0]+ε)-x[0]+x[0]+x[0]+x[0]*1*x[0]+x[0]/(x[0]
# +ε)+x[0]+x[0]+x[0]+x[0]*1/(x[0]+ε)+x[0]+x[0]-x[0]+x[0]+x[0]+x[0]*x[0]+x[0]*x[0]+
# x[0]-x[0]+x[0]*x[0]+x[0]*x[0]/(x[0]+ε)+x[0]-x[0]*x[0]*x[0]*x[0]*x[0]/(x[0]+ε)/(x
# [0]+ε)*x[0]/(x[0]+ε)+x[0]+x[0]+x[0]+1+1+x[0]/(x[0]+ε)+x[0]+x[0]+x[0]+x[0]+x[0]+x
# [0]+x[0]+x[0]*x[0]/1+x[0]+x[0]-0+x[0]-x[0]/(x[0]+ε)+x[0]+x[0]*x[0]+x[0]*x[0]+x[0
# ]-x[0]+x[0]*x[0]+x[0]*x[0]/(x[0]+ε)+x[0]+x[0]*x[0]+x[0]*x[0]*x[0]*x[0]/1+x[0]+x[
# 0]/(x[0]+ε)-x[0]*x[0]/(x[0]+ε)+x[0]/(x[0]+ε)*x[0]+x[0]+1/(x[0]+ε)+x[0]/(x[0]+ε)-
# 0+x[0]
#
# Training Fitness:  11529880.313152678
# Depth:  17
# Length of the genome:  291
# Used portion of the genome: 0.86
#
#
# Currently on run 30 of 32
# gen	invalid	avg        	std    	min        	max        	fitness_test	best_ind_length	avg_length	max_length	selection_time	generation_time
# 0  	0      	1.17825e+07	4808.08	1.17644e+07	1.17959e+07	nan         	22             	8.08      	22        	0             	0.0141635
# 1  	66     	1.17801e+07	4217.98	1.17644e+07	1.17913e+07	nan         	22             	9.575     	29        	0.00125217    	0.0801902
# 2  	41     	1.17776e+07	4709.94	1.17599e+07	1.17867e+07	nan         	17             	13.345    	32        	0.00149179    	0.0341933
# 3  	27     	1.17753e+07	5334.47	1.17599e+07	1.17867e+07	nan         	17             	16.275    	39        	0.00127769    	0.0316162
# 4  	23     	1.17727e+07	5540.76	1.17599e+07	1.17871e+07	nan         	17             	18.58     	40        	0.00122523    	0.0314214
# 5  	23     	1.17688e+07	6690.22	1.17383e+07	1.17913e+07	nan         	47             	21.8      	47        	0.0013051     	0.0340335
# 6  	30     	1.17652e+07	8757.1 	1.17338e+07	1.17867e+07	nan         	57             	26.405    	57        	0.00126696    	0.0348842
# 7  	17     	1.1759e+07 	11669.6	1.17119e+07	1.17831e+07	nan         	77             	32.94     	77        	0.0012579     	0.0400677
# 8  	26     	1.17531e+07	13274.5	1.17033e+07	1.17776e+07	nan         	95             	39.91     	95        	0.00123644    	0.0491736
# 9  	38     	1.17476e+07	16515.8	1.17033e+07	1.17867e+07	nan         	95             	46.555    	100       	0.00126624    	0.0527499
# 10 	34     	1.17412e+07	19576  	1.16859e+07	1.17867e+07	nan         	114            	57.445    	116       	0.00124407    	0.0605462
# 11 	38     	1.17359e+07	22481.8	1.16785e+07	1.17822e+07	nan         	120            	68.9      	138       	0.00119328    	0.066304
# 12 	50     	1.17302e+07	28004.2	1.166e+07  	1.17776e+07	nan         	140            	82.505    	157       	0.00264883    	0.0901206
# 13 	47     	1.17246e+07	32741.4	1.16481e+07	1.17776e+07	nan         	149            	92.855    	202       	0.0011971     	0.0891452
# 14 	44     	1.17206e+07	33687.5	1.16429e+07	1.17822e+07	nan         	155            	107.475   	222       	0.00116563    	0.0853448
# 15 	43     	1.17157e+07	35516.2	1.16075e+07	1.17822e+07	nan         	200            	119.025   	240       	0.00129938    	0.0840433
# 16 	33     	1.17005e+07	40397.4	1.15777e+07	1.17776e+07	nan         	227            	127.045   	297       	0.00125861    	0.0953348
# 17 	53     	1.17023e+07	44867.8	1.15777e+07	1.17867e+07	nan         	227            	145.515   	354       	0.0021472     	0.10378
# 18 	56     	1.16982e+07	50444.6	1.15777e+07	1.17867e+07	nan         	227            	163.665   	329       	0.0012269     	0.102333
# 19 	57     	1.17012e+07	50379  	1.15777e+07	1.17822e+07	nan         	227            	181.75    	403       	0.00245047    	0.102092
# 20 	52     	1.16976e+07	56854.9	1.15274e+07	1.17867e+07	nan         	302            	190.725   	403       	0.00120401    	0.107724
# Best individual:
#  x[0]*x[0]+x[0]-0-0*x[0]/(x[0]+ε)+x[0]/(x[0]+ε)/(x[0]+ε)+x[0]/(x[0]+ε)-x[0]+x[0]/
# (x[0]+ε)/(x[0]+ε)+x[0]*x[0]+x[0]+x[0]*x[0]/(x[0]+ε)*x[0]+x[0]+x[0]*x[0]*x[0]/(x[
# 0]+ε)+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+0+x[0]+x[0]+x[0]*x[0]+0-x[0]/(
# x[0]+ε)+x[0]/(x[0]+ε)*x[0]+x[0]/(x[0]+ε)/(x[0]+ε)/(x[0]+ε)+x[0]*x[0]*x[0]+x[0]-x
# [0]+x[0]*x[0]+x[0]/(x[0]+ε)*x[0]/(x[0]+ε)+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]/(x[0]+ε)*
# x[0]*x[0]+x[0]+x[0]+x[0]+x[0]+x[0]*x[0]+x[0]/(x[0]+ε)*x[0]/(x[0]+ε)+x[0]+x[0]+x[
# 0]*x[0]/(x[0]+ε)*x[0]/(x[0]+ε)+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]+x[0]*x[0]+x[0]/
# (x[0]+ε)*x[0]+x[0]/(x[0]+ε)+x[0]/(x[0]+ε)*x[0]+x[0]/(x[0]+ε)+x[0]+x[0]+x[0]/1+x[
# 0]+x[0]*x[0]+x[0]+x[0]/(x[0]+ε)/(x[0]+ε)*x[0]*x[0]+x[0]+x[0]*x[0]*x[0]/(x[0]+ε)/
# (x[0]+ε)+x[0]+x[0]*x[0]+1/(x[0]+ε)
#
# Training Fitness:  11527429.309986576
# Depth:  14
# Length of the genome:  302
# Used portion of the genome: 0.87
#
#
# Currently on run 31 of 32
# gen	invalid	avg        	std    	min        	max        	fitness_test	best_ind_length	avg_length	max_length	selection_time	generation_time
# 0  	0      	1.17822e+07	4570.43	1.17676e+07	1.17959e+07	8.42461e+06 	22             	8.535     	22        	0             	0.00857687
# 1  	73     	1.178e+07  	4056.99	1.17676e+07	1.17913e+07	8.42461e+06 	22             	10.09     	32        	0.00121593    	0.0727158
# 2  	31     	1.17778e+07	4519.16	1.17659e+07	1.17903e+07	nan         	34             	13.71     	34        	0.00103354    	0.0378206
# 3  	27     	1.17749e+07	4648.46	1.17595e+07	1.17863e+07	8.42461e+06 	24             	16.04     	34        	0.00109291    	0.0362818
# 4  	14     	1.17716e+07	6094.98	1.17508e+07	1.17867e+07	nan         	25             	19.01     	37        	0.00111699    	0.0544345
# 5  	22     	1.17676e+07	7578.53	1.17431e+07	1.17867e+07	nan         	46             	22.285    	48        	0.00115657    	0.0598185
# 6  	22     	1.17637e+07	10117.7	1.17241e+07	1.17826e+07	nan         	68             	26.7      	69        	0.00110745    	0.0547955
# 7  	22     	1.1757e+07 	14459.7	1.17101e+07	1.17867e+07	nan         	75             	32.955    	89        	0.00117183    	0.0562983
# 8  	27     	1.17512e+07	16740.1	1.16777e+07	1.17867e+07	nan         	85             	39.8      	109       	0.00122452    	0.0466678
# 9  	22     	1.174e+07  	22640.4	1.1666e+07 	1.17867e+07	nan         	79             	48.04     	129       	0.00121927    	0.0592091
# 10 	35     	1.17322e+07	29050.2	1.16159e+07	1.17867e+07	nan         	111            	57.83     	130       	0.00115418    	0.0624225
# 11 	42     	1.1722e+07 	35285.8	1.16159e+07	1.17785e+07	nan         	111            	71.565    	174       	0.0012908     	0.0734501
# 12 	40     	1.17136e+07	36596.1	1.16027e+07	1.17822e+07	nan         	127            	87.495    	188       	0.00214028    	0.101358
# 13 	43     	1.17095e+07	42471.7	1.16027e+07	1.17818e+07	nan         	127            	101.565   	269       	0.00115585    	0.0783343
# 14 	42     	1.1694e+07 	47690  	1.15835e+07	1.17822e+07	nan         	142            	112.145   	271       	0.00126004    	0.088562
# 15 	55     	1.16935e+07	51143.6	1.15308e+07	1.17833e+07	nan         	209            	122.235   	261       	0.00121808    	0.0956943
# 16 	60     	1.16922e+07	57204.9	1.15308e+07	1.17902e+07	nan         	209            	137.015   	378       	0.00219893    	0.09161
# 17 	53     	1.16895e+07	52062.1	1.15308e+07	1.17822e+07	nan         	209            	152.575   	407       	0.00145841    	0.0904286
# 18 	42     	1.16759e+07	64665  	1.14884e+07	1.17781e+07	nan         	230            	174.84    	400       	0.00126696    	0.098496
# 19 	61     	1.16677e+07	65847.9	1.14837e+07	1.17822e+07	nan         	450            	187.43    	450       	0.00136161    	0.112379
# 20 	70     	1.16745e+07	70475.3	1.14732e+07	1.17822e+07	nan         	239            	206.39    	574       	0.00117755    	0.112771
# Best individual:
#  x[0]+x[0]+x[0]*x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]/(x[0]
# +ε)*x[0]+x[0]+x[0]/(x[0]+ε)+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]/(x[0]+ε)+x[0]+x[0]+x[0
# ]*x[0]+x[0]+x[0]-x[0]/(x[0]+ε)*x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]
# *x[0]-x[0]+x[0]+x[0]+x[0]+x[0]*x[0]+x[0]+x[0]/(x[0]+ε)+x[0]/(x[0]+ε)*x[0]+x[0]+x
# [0]+x[0]*x[0]/(x[0]+ε)+x[0]*x[0]/(x[0]+ε)/(x[0]+ε)+x[0]+x[0]/(x[0]+ε)+x[0]*x[0]+
# x[0]*x[0]+x[0]+x[0]/(x[0]+ε)+x[0]+0/(x[0]+ε)/(x[0]+ε)*x[0]+x[0]+x[0]*x[0]/(x[0]+
# ε)*x[0]+x[0]+x[0]-x[0]+x[0]/(x[0]+ε)+x[0]+x[0]*x[0]+x[0]+x[0]+x[0]+x[0]+x[0]/(x[
# 0]+ε)*x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]+x[0]*x[0]/(x[0]+ε)-x[0]*x[0]/(x[0]+ε)/(
# x[0]+ε)+x[0]
#
# Training Fitness:  11473172.403744234
# Depth:  16
# Length of the genome:  239
# Used portion of the genome: 0.97

# %%
#plot statistics:
x = np.arange(0, MAX_GENERATIONS+1)
avgArray = np.array(avgListFitness)
stdArray = np.array(stdListFitness)
minArray = np.array(minListFitness)
maxArray = np.array(maxListFitness)

plt.xlabel('Generation')
plt.ylabel('Fitness')
plt.title('Fitness Symbollic Regression')
plt.errorbar(x, avgArray.mean(0), yerr=stdArray.mean(0),label="Average",color="Red")
plt.errorbar(x, minArray.mean(0), yerr=minArray.std(0),label="Best", color="Green")
# plt.errorbar(x, maxArray.mean(0), yerr=maxArray.std(0),label="Best", color="Blue")
plt.legend()
plt.show()

# %%
x = np.arange(0, MAX_GENERATIONS+1)
avgSizeArray = np.array(avgListSize)
bestSizeArray = np.array(bestListSize)
maxSizeArray = np.array(maxListSize)


plt.errorbar(x, avgSizeArray.mean(0), yerr=avgSizeArray.std(0),label="Average",color="Red")
# plt.errorbar(x, maxSizeArray.mean(0), yerr=maxSizeArray.std(0), label="Max", color="Green")
plt.errorbar(x, bestSizeArray.mean(0), yerr=bestSizeArray.std(0), label="Best", color="Blue")
plt.legend(fontsize=12)
plt.xlabel('Generations', fontsize=14)
plt.ylabel('Genome Length', fontsize=14)
plt.title('Genome Length over Generations', fontsize=16)
plt.legend()
plt.show()

# %%
with open("out-files/statistics-cfg.txt") as file:
    content = [line.strip() for line in file.readlines()]

# %%
cfg1 = (pd.Series(content).value_counts() / 4)[0]
cfg2 = (pd.Series(content).value_counts() / 4)[2]
ag = 0

# %%
plt.bar(["CFG", "AG"], [cfg1+cfg2, ag])
plt.title("Division by zero per run")
plt.show()
